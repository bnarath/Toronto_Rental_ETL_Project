# %% [markdown]
# Toronto Police Service Community Asset Portal
# ---
#
# The website of interest is  dynamic, meaning it needs to interacted with inorder for the data of interest to be accessed from back-end server then displayed on the webpage.
#
# As such, Selenium, with its more nuanced tools for navigating webpages, is a better choice for web scrapping than splinter.

# %%
#import libraries
from bs4 import BeautifulSoup as BS
from selenium import webdriver
from pandas import pandas as pd

from selenium.webdriver.support.ui import Select

import time

# %%
#open url

DRIVER_PATH = "driver/chromedriver.exe"
driver = webdriver.Chrome(executable_path=DRIVER_PATH)
driver.get("https://torontops.maps.arcgis.com/home/item.html?id=077c19d8628b44c7ab9f0fff75a55211&view=list&sortOrder=true&sortField=defaultFSOrder#data")

# %% [raw]
# The options are as follows(within <select data-dojo-attach-point="layerSelect" class="inline-block leader-0" selected="0">):
#
# <option value="0">Health Services</option>
# <option value="1">Community Services</option>
# <option value="2">Food &amp; Housing</option>
# <option value="3">Law &amp; Government</option>
# <option value="4">Education &amp; Employment</option>
# <option value="5">Financial Services</option>
# <option value="6">Transportation</option>
# <option value="7">Other</option>
# <option value="8">ReceivedData</option>
#
# Option 8 is a collapse of all the other options, however it does not include a classifcation column.
#
# note: tried to iterate the options with 30 sec pause, but the website refused after the second loop.

# %%
# health services

# select dropdown menu with data tabel option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Health Services")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")

#create dataframe
health_services = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    health_services.append(row)

health_services_df = pd.concat(health_services)

# %%
#headers

list_columns = pd.read_html(str(html_table[0]), flavor='bs4')
row = pd.concat(list_columns)

row

headers = list(row)

# %%
health_services_df.set_axis(headers, axis=1, inplace=True)

health_services_df["category"] = "health services"

# %%
#verify

health_services_df.head(3)
# Out:
#                          Agency Name                          Site Name  \
# 0  Jack Nathan Health Medical Clinic  Jack Nathan Health Medical Clinic
# 0            One Stop Medical Center            One Stop Medical Center
# 0        MD Connected Walk-in Clinic        MD Connected Walk-in Clinic
#
#                         Service Name  Service Name (2)  \
# 0  Jack Nathan Health Medical Clinic               NaN
# 0            One Stop Medical Center               NaN
# 0        MD Connected Walk-in Clinic               NaN
#
#                                              Address    Site City  \
# 0             5995 Steeles Ave E Toronto, ON M1V 5P7      Toronto
# 0  3585 Lawrence Ave E, Suite 1A Toronto, ON M1G 1P4      Toronto
# 0  2251 Lawrence Ave E, Unit 102 Scarborough, ON ...  Scarborough
#
#   Site Postal Code                           Application  Crisis_Phone  \
# 0          M1V 5P7        Drop-in * no referral required           NaN
# 0          M1G 1P4        Drop-in * no referral required           NaN
# 0          M1P 2P5  Call or visit * no referral required           NaN
#
#                                Description (Service)  ...  \
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic * doctors and nurses as...  ...
#
#           Date Updated                   DD Code   Physical Access SINV (TO)  \
# 0   9/19/2019, 8:00 PM  Health (Walk In Clinics)           Unknown       NaN
# 0    3/2/2020, 7:00 PM  Health (Walk In Clinics)  Fully Accessible       NaN
# 0  10/20/2019, 8:00 PM  Health (Walk In Clinics)  Fully Accessible       NaN
#
#                   DD Code.1         Category  \
# 0  Health (Walk In Clinics)  Health Services
# 0  Health (Walk In Clinics)  Health Services
# 0  Health (Walk In Clinics)  Health Services
#
#                            FULL_NAME       LAST_UPDATED OBJECTID  \
# 0  Jack Nathan Health Medical Clinic  3/6/2020, 9:51 AM        1
# 0            One Stop Medical Center  3/6/2020, 9:51 AM        2
# 0        MD Connected Walk-in Clinic  3/6/2020, 9:51 AM        3
#
#           category
# 0  health services
# 0  health services
# 0  health services
#
# [3 rows x 33 columns]

# %%
# community services

# select dropdown menu with data tabel option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Community Services")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-14-d5f66ad55804> in <module>
#       6
#       7 # select data table
# ----> 8 select.select_by_visible_text("Community Services")
#       9
#      10 time.sleep(5)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\select.py in select_by_visible_text(self, text)
#     118         matched = False
#     119         for opt in opts:
# --> 120             self._setSelected(opt)
#     121             if not self.is_multiple:
#     122                 return
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\select.py in _setSelected(self, option)
#     210     def _setSelected(self, option):
#     211         if not option.is_selected():
# --> 212             option.click()
#     213
#     214     def _unsetSelected(self, option):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: call function result missing 'value'
#   (Session info: chrome=84.0.4147.105)
#   (Driver info: chromedriver=2.34.522940 (1a76f96f66e3ca7b8e57d503b4dd3bccfba87af1),platform=Windows NT 10.0.18362 x86_64)

# %%
#create dataframe
community_services = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    community_services.append(row)

community_services_df = pd.concat(community_services)

#clean-up
community_services_df.set_axis(headers, axis=1, inplace=True)

community_services_df["category"] = "community services"

community_services_df.head(3)
# Out:
#                          Agency Name                          Site Name  \
# 0  Jack Nathan Health Medical Clinic  Jack Nathan Health Medical Clinic
# 0            One Stop Medical Center            One Stop Medical Center
# 0        MD Connected Walk-in Clinic        MD Connected Walk-in Clinic
#
#                         Service Name  Service Name (2)  \
# 0  Jack Nathan Health Medical Clinic               NaN
# 0            One Stop Medical Center               NaN
# 0        MD Connected Walk-in Clinic               NaN
#
#                                              Address    Site City  \
# 0             5995 Steeles Ave E Toronto, ON M1V 5P7      Toronto
# 0  3585 Lawrence Ave E, Suite 1A Toronto, ON M1G 1P4      Toronto
# 0  2251 Lawrence Ave E, Unit 102 Scarborough, ON ...  Scarborough
#
#   Site Postal Code                           Application  Crisis_Phone  \
# 0          M1V 5P7        Drop-in * no referral required           NaN
# 0          M1G 1P4        Drop-in * no referral required           NaN
# 0          M1P 2P5  Call or visit * no referral required           NaN
#
#                                Description (Service)  ...  \
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic * doctors and nurses as...  ...
#
#           Date Updated                   DD Code   Physical Access SINV (TO)  \
# 0   9/19/2019, 8:00 PM  Health (Walk In Clinics)           Unknown       NaN
# 0    3/2/2020, 7:00 PM  Health (Walk In Clinics)  Fully Accessible       NaN
# 0  10/20/2019, 8:00 PM  Health (Walk In Clinics)  Fully Accessible       NaN
#
#                   DD Code.1         Category  \
# 0  Health (Walk In Clinics)  Health Services
# 0  Health (Walk In Clinics)  Health Services
# 0  Health (Walk In Clinics)  Health Services
#
#                            FULL_NAME       LAST_UPDATED OBJECTID  \
# 0  Jack Nathan Health Medical Clinic  3/6/2020, 9:51 AM        1
# 0            One Stop Medical Center  3/6/2020, 9:51 AM        2
# 0        MD Connected Walk-in Clinic  3/6/2020, 9:51 AM        3
#
#              category
# 0  community services
# 0  community services
# 0  community services
#
# [3 rows x 33 columns]

# %%
# food & Housing

# select dropdown menu with data tabel option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Food & Housing")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-18-5270e255c563> in <module>
#       6
#       7 # select data table
# ----> 8 select.select_by_visible_text("Food & Housing")
#       9
#      10 time.sleep(5)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\select.py in select_by_visible_text(self, text)
#     118         matched = False
#     119         for opt in opts:
# --> 120             self._setSelected(opt)
#     121             if not self.is_multiple:
#     122                 return
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\select.py in _setSelected(self, option)
#     210     def _setSelected(self, option):
#     211         if not option.is_selected():
# --> 212             option.click()
#     213
#     214     def _unsetSelected(self, option):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: call function result missing 'value'
#   (Session info: chrome=84.0.4147.105)
#   (Driver info: chromedriver=2.34.522940 (1a76f96f66e3ca7b8e57d503b4dd3bccfba87af1),platform=Windows NT 10.0.18362 x86_64)

# %%
#create dataframe
food_housing = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    food_housing.append(row)

food_housing_df = pd.concat(food_housing)

#clean-up
food_housing_df.set_axis(headers, axis=1, inplace=True)

food_housing_df["category"] = "Food & Housing"

food_housing_df.head(3)
# Out:
#                          Agency Name                          Site Name  \
# 0  Jack Nathan Health Medical Clinic  Jack Nathan Health Medical Clinic
# 0            One Stop Medical Center            One Stop Medical Center
# 0        MD Connected Walk-in Clinic        MD Connected Walk-in Clinic
#
#                         Service Name  Service Name (2)  \
# 0  Jack Nathan Health Medical Clinic               NaN
# 0            One Stop Medical Center               NaN
# 0        MD Connected Walk-in Clinic               NaN
#
#                                              Address    Site City  \
# 0             5995 Steeles Ave E Toronto, ON M1V 5P7      Toronto
# 0  3585 Lawrence Ave E, Suite 1A Toronto, ON M1G 1P4      Toronto
# 0  2251 Lawrence Ave E, Unit 102 Scarborough, ON ...  Scarborough
#
#   Site Postal Code                           Application  Crisis_Phone  \
# 0          M1V 5P7        Drop-in * no referral required           NaN
# 0          M1G 1P4        Drop-in * no referral required           NaN
# 0          M1P 2P5  Call or visit * no referral required           NaN
#
#                                Description (Service)  ...  \
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic * doctors and nurses as...  ...
#
#           Date Updated                   DD Code   Physical Access SINV (TO)  \
# 0   9/19/2019, 8:00 PM  Health (Walk In Clinics)           Unknown       NaN
# 0    3/2/2020, 7:00 PM  Health (Walk In Clinics)  Fully Accessible       NaN
# 0  10/20/2019, 8:00 PM  Health (Walk In Clinics)  Fully Accessible       NaN
#
#                   DD Code.1         Category  \
# 0  Health (Walk In Clinics)  Health Services
# 0  Health (Walk In Clinics)  Health Services
# 0  Health (Walk In Clinics)  Health Services
#
#                            FULL_NAME       LAST_UPDATED OBJECTID  \
# 0  Jack Nathan Health Medical Clinic  3/6/2020, 9:51 AM        1
# 0            One Stop Medical Center  3/6/2020, 9:51 AM        2
# 0        MD Connected Walk-in Clinic  3/6/2020, 9:51 AM        3
#
#          category
# 0  Food & Housing
# 0  Food & Housing
# 0  Food & Housing
#
# [3 rows x 33 columns]

# %%
# Law & Government

# select dropdown menu with data tabel option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Law & Government")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")

# %%
#create dataframe

law_government= []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    law_government.append(row)

law_government= pd.concat(law_government)

#clean-up
law_government_df.set_axis(headers, axis=1, inplace=True)

law_government_df["category"] = "Law & Government"

law_government_df.head(3)
# Out:
#                                          Agency Name  \
# 0  Ontario. Ministry of the Attorney General. Fin...
# 0                    Advocacy Centre for the Elderly
# 0                         ARCH Disability Law Centre
#
#                                            Site Name  \
# 0  Ontario. Ministry of the Attorney General. Fin...
# 0                    Advocacy Centre for the Elderly
# 0                         ARCH Disability Law Centre
#
#                                         Service Name Service Name (2)  \
# 0  Ontario. Ministry of the Attorney General. Fin...              NaN
# 0                    Advocacy Centre for the Elderly              NaN
# 0                         ARCH Disability Law Centre              NaN
#
#                                           Address Site City Site Postal Code  \
# 0                                     Toronto, ON   Toronto              NaN
# 0     2 Carlton St, Suite 701 Toronto, ON M5B 1J3   Toronto          M5B 1J3
# 0  55 University Ave, 15th Fl Toronto, ON M5J 2H7   Toronto          M5J 2H7
#
#                                          Application Crisis_Phone  \
# 0  For homicides that occur on or after January 1...          NaN
# 0                               Call for information          NaN
# 0  Call to speak with Intake Coordinator and Huma...          NaN
#
#                                Description (Service)  ...  \
# 0  Time limited initiative of the Ontario Governm...  ...
# 0  Community legal clinic * representation in cas...  ...
# 0  Community legal clinic Summary Advice and Refe...  ...
#
#           Date Updated                    DD Code  \
# 0    4/1/2019, 8:00 PM            Legal (General)
# 0   1/19/2020, 7:00 PM  Legal (Legal Aid Clinics)
# 0  10/24/2019, 8:00 PM  Legal (Legal Aid Clinics)
#
#                                      Physical Access SINV (TO)  \
# 0                                     Not Applicable       NaN
# 0  Designated parking at entrance - garage entran...       NaN
# 0  Wheelchair accessible automatic main entrance ...       NaN
#
#                    DD Code.1          Category  \
# 0            Legal (General)  Law & Government
# 0  Legal (Legal Aid Clinics)  Law & Government
# 0  Legal (Legal Aid Clinics)  Law & Government
#
#                                            FULL_NAME       LAST_UPDATED  \
# 0  Ontario. Ministry of the Attorney General. Fin...  3/6/2020, 9:51 AM
# 0                    Advocacy Centre for the Elderly  3/6/2020, 9:51 AM
# 0                         ARCH Disability Law Centre  3/6/2020, 9:51 AM
#
#   OBJECTID          category
# 0      338  Law & Government
# 0      342  Law & Government
# 0      343  Law & Government
#
# [3 rows x 33 columns]

# %%
# Education & Employment

# select dropdown menu with data tabel option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Education & Employment")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")

# %%
#create dataframe
education_employment = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    education_employment.append(row)

education_employment_df = pd.concat(education_employment)

#clean-up
education_employment_df.set_axis(headers, axis=1, inplace=True)

education_employment_df["category"] = "Education & Employment"

education_employment_df.head(3)
# Out:
#                           Agency Name                           Site Name  \
# 0                         JVS Toronto                         Head Office
# 0  Ontario Special Education Tribunal  Ontario Special Education Tribunal
# 0      Ontario. Pay Equity Commission      Ontario. Pay Equity Commission
#
#                              Service Name Service Name (2)  \
# 0  Ontario Employment Assistance Services              NaN
# 0      Ontario Special Education Tribunal              NaN
# 0          Ontario. Pay Equity Commission              NaN
#
#                                           Address Site City Site Postal Code  \
# 0                 74 Tycos Dr Toronto, ON M6B 1V9   Toronto          M6B 1V9
# 0           655 Bay St, 14 Fl Toronto, ON M7A 2A3   Toronto          M7A 2A3
# 0  180 Dundas St W, Suite 300 Toronto, ON M7A 2S6   Toronto          M7A 2S6
#
#                                          Application Crisis_Phone  \
# 0  Call ahead * some providers may require a refe...          NaN
# 0  Call, send email, or visit website for informa...          NaN
# 0  Call or download an application form from the ...          NaN
#
#                                Description (Service)  ...        Date Updated  \
# 0  Offers employment services which may include d...  ...  7/24/2018, 8:00 PM
# 0  Adjudicative tribunal * hears appeals from par...  ...  5/12/2019, 8:00 PM
# 0  Pay Equity Office Responsible for implementing...  ...  8/21/2019, 8:00 PM
#
#                             DD Code  \
# 0  Employment (Vocational Training)
# 0                         Education
# 0              Employment (General)
#
#                                      Physical Access SINV (TO)  \
# 0  Wheelchair accessible building including main ...       NaN
# 0  Wheelchair accessible automatic main entrance ...       NaN
# 0  Designated parking at entrance * wheelchair ac...       NaN
#
#                           DD Code.1                Category  \
# 0  Employment (Vocational Training)  Education & Employment
# 0                         Education  Education & Employment
# 0              Employment (General)  Education & Employment
#
#                                            FULL_NAME       LAST_UPDATED  \
# 0  JVS Toronto. Head Office. Ontario Employment A...  3/6/2020, 9:51 AM
# 0                 Ontario Special Education Tribunal  3/6/2020, 9:51 AM
# 0                     Ontario. Pay Equity Commission  3/6/2020, 9:51 AM
#
#   OBJECTID                category
# 0      340  Education & Employment
# 0      358  Education & Employment
# 0      370  Education & Employment
#
# [3 rows x 33 columns]

# %%
# Financial Services

# select dropdown menu with data tabel option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Financial Services")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-36-6933168a1f42> in <module>
#       6
#       7 # select data table
# ----> 8 select.select_by_visible_text("Financial Services")
#       9
#      10 time.sleep(5)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\select.py in select_by_visible_text(self, text)
#     118         matched = False
#     119         for opt in opts:
# --> 120             self._setSelected(opt)
#     121             if not self.is_multiple:
#     122                 return
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\support\select.py in _setSelected(self, option)
#     210     def _setSelected(self, option):
#     211         if not option.is_selected():
# --> 212             option.click()
#     213
#     214     def _unsetSelected(self, option):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: call function result missing 'value'
#   (Session info: chrome=84.0.4147.105)
#   (Driver info: chromedriver=2.34.522940 (1a76f96f66e3ca7b8e57d503b4dd3bccfba87af1),platform=Windows NT 10.0.18362 x86_64)

# %%
#create dataframe
financial_services = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    financial_services.append(row)

financial_services_df = pd.concat(financial_services)

#clean-up
financial_services_df.set_axis(headers, axis=1, inplace=True)

financial_services_df["category"] = "Financial Services"

financial_services_df.head(3)
# Out:
#                                          Agency Name  \
# 0  Ontario. Ministry of the Attorney General. Fin...
# 0                    Advocacy Centre for the Elderly
# 0                         ARCH Disability Law Centre
#
#                                            Site Name  \
# 0  Ontario. Ministry of the Attorney General. Fin...
# 0                    Advocacy Centre for the Elderly
# 0                         ARCH Disability Law Centre
#
#                                         Service Name Service Name (2)  \
# 0  Ontario. Ministry of the Attorney General. Fin...              NaN
# 0                    Advocacy Centre for the Elderly              NaN
# 0                         ARCH Disability Law Centre              NaN
#
#                                           Address Site City Site Postal Code  \
# 0                                     Toronto, ON   Toronto              NaN
# 0     2 Carlton St, Suite 701 Toronto, ON M5B 1J3   Toronto          M5B 1J3
# 0  55 University Ave, 15th Fl Toronto, ON M5J 2H7   Toronto          M5J 2H7
#
#                                          Application Crisis_Phone  \
# 0  For homicides that occur on or after January 1...          NaN
# 0                               Call for information          NaN
# 0  Call to speak with Intake Coordinator and Huma...          NaN
#
#                                Description (Service)  ...  \
# 0  Time limited initiative of the Ontario Governm...  ...
# 0  Community legal clinic * representation in cas...  ...
# 0  Community legal clinic Summary Advice and Refe...  ...
#
#           Date Updated                    DD Code  \
# 0    4/1/2019, 8:00 PM            Legal (General)
# 0   1/19/2020, 7:00 PM  Legal (Legal Aid Clinics)
# 0  10/24/2019, 8:00 PM  Legal (Legal Aid Clinics)
#
#                                      Physical Access SINV (TO)  \
# 0                                     Not Applicable       NaN
# 0  Designated parking at entrance - garage entran...       NaN
# 0  Wheelchair accessible automatic main entrance ...       NaN
#
#                    DD Code.1          Category  \
# 0            Legal (General)  Law & Government
# 0  Legal (Legal Aid Clinics)  Law & Government
# 0  Legal (Legal Aid Clinics)  Law & Government
#
#                                            FULL_NAME       LAST_UPDATED  \
# 0  Ontario. Ministry of the Attorney General. Fin...  3/6/2020, 9:51 AM
# 0                    Advocacy Centre for the Elderly  3/6/2020, 9:51 AM
# 0                         ARCH Disability Law Centre  3/6/2020, 9:51 AM
#
#   OBJECTID            category
# 0      338  Financial Services
# 0      342  Financial Services
# 0      343  Financial Services
#
# [3 rows x 33 columns]

# %%
# Transportation

# select dropdown menu with data label option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Transportation")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")

# %%
#create dataframe
transportation = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    transportation.append(row)

transportation_df = pd.concat(transportation)

#clean-up
transportation_df.set_axis(headers, axis=1, inplace=True)

transportation_df["category"] = "Transportation"

transportation_df.head(3)
# Out:
#                   Agency Name    Site Name Service Name Service Name (2)  \
# 0                  iRide Plus   iRide Plus   iRide Plus              NaN
# 0                   Metrolinx    Metrolinx    Metrolinx              NaN
# 0  Toronto Transit Commission  Wheel-Trans  Wheel-Trans              NaN
#
#                                     Address Site City Site Postal Code  \
# 0                                       NaN       NaN              NaN
# 0         97 Front St W Toronto, ON M5J 1E6   Toronto          M5J 1E6
# 0  580 Commissioners St Toronto, ON M4M 1A7   Toronto          M4M 1A7
#
#                                          Application  Crisis_Phone  \
# 0  A brief assessment over the phone, or in perso...           NaN
# 0                                     Not applicable           NaN
# 0  Call or visit website for application form * i...           NaN
#
#                                Description (Service)  ...        Date Updated  \
# 0  Transportation service that provides door-to-d...  ...  3/13/2019, 8:00 PM
# 0  Planning and delivery of a regional public tra...  ...  8/20/2019, 8:00 PM
# 0  Specialized public transportation service usin...  ...  4/25/2019, 8:00 PM
#
#           DD Code                                    Physical Access  \
# 0  Transportation                               Partially Accessible
# 0  Transportation                                            Unknown
# 0  Transportation  Wheelchair accessible building including main ...
#
#   SINV (TO)       DD Code.1        Category  \
# 0       NaN  Transportation  Transportation
# 0       NaN  Transportation  Transportation
# 0       NaN  Transportation  Transportation
#
#                                  FULL_NAME       LAST_UPDATED OBJECTID  \
# 0                               iRide Plus  3/6/2020, 9:51 AM      285
# 0                                Metrolinx  3/6/2020, 9:51 AM      715
# 0  Toronto Transit Commission. Wheel-Trans  3/6/2020, 9:51 AM     1024
#
#          category
# 0  Transportation
# 0  Transportation
# 0  Transportation
#
# [3 rows x 33 columns]

# %%
# Other

# select dropdown menu with data label option

select = Select(driver.find_element_by_xpath("//select[@data-dojo-attach-point = 'layerSelect']"))

# select data table 
select.select_by_visible_text("Other")
    
time.sleep(5)
    
# parse web page
page_source = driver.page_source
soup = BS(page_source, 'html.parser')

html_table = soup.find_all("table", class_="dgrid-row-table")

# %%
#create dataframe
other = []

for table in html_table[1:]:
    list_columns = pd.read_html(str(table), flavor='bs4')
    row = pd.concat(list_columns)
    other.append(row)

other_df = pd.concat(other)

#clean-up
other_df.set_axis(headers, axis=1, inplace=True)

other_df["category"] = "Other"

other_df.head(3)
# Out:
#                   Agency Name                   Site Name  \
# 0    Blue Rose Medical Centre    Blue Rose Medical Centre
# 0  HealthSmart Medical Clinic  HealthSmart Medical Clinic
# 0             City of Toronto             City of Toronto
#
#                           Service Name                Service Name (2)  \
# 0             Blue Rose Medical Centre                             NaN
# 0           HealthSmart Medical Clinic                             NaN
# 0  Seniors Services and Long-Term Care  Homemakers and Nurses Services
#
#                                              Address    Site City  \
# 0  1910 Kennedy Rd, Units 5 and 6 Toronto, ON M1P...      Toronto
# 0  2425 Eglinton Ave E, Unit 12 Scarborough, ON M...  Scarborough
# 0      1530 Markham Rd Suite 502 Toronto, ON M1B 3G4      Toronto
#
#   Site Postal Code                                        Application  \
# 0          M1P 2L8                                            Walk-in
# 0          M1K 5G8                                      Call or visit
# 0          M1B 3G4  Financial assessment completed by an HMNS prog...
#
#    Crisis_Phone                              Description (Service)  ...  \
# 0           NaN  Walk-in medical clinic with associated family ...  ...
# 0           NaN  Walk-in medical clinic with associated family ...  ...
# 0           NaN  Provides homemaking services through community...  ...
#
#          Date Updated DD Code   Physical Access SINV (TO) DD Code.1 Category  \
# 0   5/5/2019, 8:00 PM     NaN  Fully Accessible       NaN       NaN      NaN
# 0   7/7/2019, 8:00 PM     NaN  Fully Accessible       NaN       NaN      NaN
# 0  6/18/2019, 8:00 PM     NaN  Fully Accessible       NaN       NaN      NaN
#
#                     FULL_NAME       LAST_UPDATED OBJECTID category
# 0    Blue Rose Medical Centre  3/6/2020, 9:51 AM       15    Other
# 0  HealthSmart Medical Clinic  3/6/2020, 9:51 AM       16    Other
# 0             City of Toronto  3/6/2020, 9:51 AM       18    Other
#
# [3 rows x 33 columns]

# %%
#create master dataframe

dataframes = [community_services_df, health_services_df, 
              financial_services_df, other_df, 
              transportation_df, law_government_df,
             food_housing_df, education_employment_df]

community_assets_df = pd.concat(dataframes)

community_assets_df.head()
# Out:
#                          Agency Name                          Site Name  \
# 0  Jack Nathan Health Medical Clinic  Jack Nathan Health Medical Clinic
# 0            One Stop Medical Center            One Stop Medical Center
# 0        MD Connected Walk-in Clinic        MD Connected Walk-in Clinic
# 0                     Autism Ontario                    Toronto Chapter
# 0           Total Care Health Centre           Total Care Health Centre
#
#                         Service Name Service Name (2)  \
# 0  Jack Nathan Health Medical Clinic              NaN
# 0            One Stop Medical Center              NaN
# 0        MD Connected Walk-in Clinic              NaN
# 0     Autism Information and Support              NaN
# 0           Total Care Health Centre              NaN
#
#                                              Address    Site City  \
# 0             5995 Steeles Ave E Toronto, ON M1V 5P7      Toronto
# 0  3585 Lawrence Ave E, Suite 1A Toronto, ON M1G 1P4      Toronto
# 0  2251 Lawrence Ave E, Unit 102 Scarborough, ON ...  Scarborough
# 0                                                NaN          NaN
# 0            3155 Eglinton Ave E Toronto, ON M1J 2G2      Toronto
#
#   Site Postal Code                              Application Crisis_Phone  \
# 0          M1V 5P7           Drop-in * no referral required          NaN
# 0          M1G 1P4           Drop-in * no referral required          NaN
# 0          M1P 2P5     Call or visit * no referral required          NaN
# 0              NaN  Registration required for most programs          NaN
# 0          M1J 2G2           Drop-in * no referral required          NaN
#
#                                Description (Service)  ...  \
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic with associated family ...  ...
# 0  Walk-in medical clinic * doctors and nurses as...  ...
# 0  Volunteer-run organization providing informati...  ...
# 0  Walk-in medical clinicOn-Site Services:pharmac...  ...
#
#           Date Updated                       DD Code   Physical Access  \
# 0   9/19/2019, 8:00 PM      Health (Walk In Clinics)           Unknown
# 0    3/2/2020, 7:00 PM      Health (Walk In Clinics)  Fully Accessible
# 0  10/20/2019, 8:00 PM      Health (Walk In Clinics)  Fully Accessible
# 0    3/2/2020, 7:00 PM  Disabilities (Developmental)    Not Applicable
# 0  11/17/2019, 7:00 PM      Health (Walk In Clinics)  Fully Accessible
#
#   SINV (TO)                     DD Code.1         Category  \
# 0       NaN      Health (Walk In Clinics)  Health Services
# 0       NaN      Health (Walk In Clinics)  Health Services
# 0       NaN      Health (Walk In Clinics)  Health Services
# 0       NaN  Disabilities (Developmental)  Health Services
# 0       NaN      Health (Walk In Clinics)  Health Services
#
#                                            FULL_NAME       LAST_UPDATED  \
# 0                  Jack Nathan Health Medical Clinic  3/6/2020, 9:51 AM
# 0                            One Stop Medical Center  3/6/2020, 9:51 AM
# 0                        MD Connected Walk-in Clinic  3/6/2020, 9:51 AM
# 0  Autism Ontario. Toronto Chapter. Autism Inform...  3/6/2020, 9:51 AM
# 0                           Total Care Health Centre  3/6/2020, 9:51 AM
#
#   OBJECTID            category
# 0        1  community services
# 0        2  community services
# 0        3  community services
# 0        4  community services
# 0        5  community services
#
# [5 rows x 33 columns]

# %%
#verify
count = 0

for df in dataframes:
    count = count + len(df)

count
# Out:
# 360

# %%
len(community_assets_df)
# Out:
# 360

# %%
community_assets_df.to_csv("data/community_assets.csv", encoding='utf-8', index=False)
